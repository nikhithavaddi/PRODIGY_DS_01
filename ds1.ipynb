# %%
import matplotlib.pyplot as plt

# Sample data (replace this with your own data)
genders = ['Male', 'Female', 'Non-Binary', 'Other']
counts = [50, 45, 3, 2]  # Replace with actual counts for each gender category

# Create a bar chart
plt.bar(genders, counts, color=['blue', 'pink', 'orange', 'gray'])
plt.title('Distribution of Genders in the Population')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()
